# %%
# %matplotlib inline
import os
import sys
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread
psp_base_dir = os.path.join('..', 'pspnet_test')
psp_model_dir = os.path.join(psp_base_dir, 'model', 'model')
cityscape_weights = os.path.join(psp_base_dir, 'model', 'model', 'pspnet101-cityscapes')
psp_code_dir = os.path.join(psp_base_dir)

# %%
import tensorflow as tf
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
sys.path.append(psp_code_dir)
from model import PSPNet101, PSPNet50
from tools import *

# %%
# TODO: Change these values to where your model files are
# ADE20k_param = {'crop_size': [473, 473],
#                 'num_classes': 150, 
#                 'model': PSPNet50,
#                 'weights_path': os.path.join(psp_model_dir, 'pspnet50-ade20k/model.ckpt-0')}

cityscapes_param = {'crop_size': [720, 720],
                    'num_classes': 19,
                    'model': PSPNet101,
                    'weights_path': os.path.join(psp_model_dir,'pspnet101-cityscapes/model.ckpt-0')}

IMAGE_MEAN = np.array((103.939, 116.779, 123.68), dtype=np.float32)
# TODO: If you want to inference on indoor data, change this value to `ADE20k_param`
param = cityscapes_param

# %%
data_path = os.path.join(psp_code_dir, 'data')
onlyfiles = [f for f in os.listdir(data_path) if os.path.isfile(os.path.join(data_path, f))]
print("Working with {0} train images".format(len(onlyfiles)))
# Out:
# Working with 8 train images

# %%
onlyfiles
# Out:
# ['king_street.jpg',
#  'sidewalk1.jpg',
#  'sidewalk2.jpg',
#  'sidewalk3.jpg',
#  'sidewalk4.jpg',
#  'sidewalk5.jpg',
#  'street_busan.jpg',
#  'street_image.png']

# %%
img_path_list = []
img_arr = []

for _file in onlyfiles:
    print(_file)
    img_path = os.path.join(data_path, str(_file))
    img_path_list.append(img_path)
    img_np, filename = load_img(img_path)
    img_shape = tf.shape(img_np)
    h, w = (tf.maximum(param['crop_size'][0], img_shape[0]), tf.maximum(param['crop_size'][1], img_shape[1]))
    img_arr.append(preprocess(img_np, h, w))
# Out:
# king_street.jpg
# successful load img: ..\pspnet_test\data\king_street.jpg
# sidewalk1.jpg
# successful load img: ..\pspnet_test\data\sidewalk1.jpg
# sidewalk2.jpg
# successful load img: ..\pspnet_test\data\sidewalk2.jpg
# sidewalk3.jpg
# successful load img: ..\pspnet_test\data\sidewalk3.jpg
# sidewalk4.jpg
# successful load img: ..\pspnet_test\data\sidewalk4.jpg
# sidewalk5.jpg
# successful load img: ..\pspnet_test\data\sidewalk5.jpg
# street_busan.jpg
# successful load img: ..\pspnet_test\data\street_busan.jpg
# street_image.png
# successful load img: ..\pspnet_test\data\street_image.png

# %%
img_arr[0]
# Out:
# <tf.Tensor 'ExpandDims:0' shape=(1, ?, ?, 3) dtype=float32>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,10))
ax1.imshow(imread(img_path_list[0]))
ax1.axis('off')

ax2.imshow(imread(img_path_list[1]))
ax2.axis('off')

ax3.imshow(imread(img_path_list[2]))
ax3.axis('off')
# Out:
# (-0.5, 959.5, 625.5, -0.5)

# %%
# Create network.
PSPNet = param['model']

# net = PSPNet({'data': img_arr[0]}, is_training=False, num_classes=param['num_classes'])
# raw_output = net.layers['conv6']

# %%
# Predictions.
preds = []

for img in img_arr :
    net = PSPNet({'data': img}, is_training=False, num_classes=param['num_classes'])
    raw_output = net.layers['conv6']
    
    img_shape = tf.shape(img)
    h, w = (tf.maximum(param['crop_size'][0], img_shape[0]), tf.maximum(param['crop_size'][1], img_shape[1]))
    raw_output_up = tf.image.resize_bilinear(raw_output, size=[h, w], align_corners=True)
    raw_output_up = tf.image.crop_to_bounding_box(raw_output_up, 0, 0, img_shape[0], img_shape[1])
    raw_output_up = tf.argmax(raw_output_up, axis=3)
    pred = decode_labels(raw_output_up, img_shape, param['num_classes'])
    preds.append(pred)
    
    tf.reset_default_graph()
    

# Init tf Session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
init = tf.global_variables_initializer()

sess.run(init)

ckpt_path = param['weights_path']
loader = tf.train.Saver(var_list=tf.global_variables())
loader.restore(sess, ckpt_path)
print("Restored model parameters from {}".format(ckpt_path))
# Out:
# WARNING:tensorflow:From C:\Users\yumin\Coding\pspnet_test\network.py:140: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From c:\users\yumin\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-cc0926e2e2f7> in <module>
#       3
#       4 for img in img_arr :
# ----> 5     net = PSPNet({'data': img}, is_training=False, num_classes=param['num_classes'])
#       6     raw_output = net.layers['conv6']
#       7
#
# ~\Coding\pspnet_test\network.py in __init__(self, inputs, trainable, is_training, num_classes)
#      51                                                        name='use_dropout')
#      52         self.is_training = is_training
# ---> 53         self.setup(is_training, num_classes)
#      54
#      55     def setup(self, is_training):
#
# ~\Coding\pspnet_test\model.py in setup(self, is_training, num_classes)
#      13         '''
#      14         (self.feed('data')
# ---> 15              .conv(3, 3, 64, 2, 2, biased=False, relu=False, padding='SAME', name='conv1_1_3x3_s2')
#      16              .batch_normalization(relu=False, name='conv1_1_3x3_s2_bn')
#      17              .relu(name='conv1_1_3x3_s2_bn_relu')
#
# ~\Coding\pspnet_test\network.py in layer_decorated(self, *args, **kwargs)
#      24             layer_input = list(self.terminals)
#      25         # Perform the operation and get the output.
# ---> 26         layer_output = op(self, layer_input, *args, **kwargs)
#      27         # Add to layer LUT.
#      28         self.layers[name] = layer_output
#
# ~\Coding\pspnet_test\network.py in conv(self, input, k_h, k_w, c_o, s_h, s_w, name, relu, padding, group, biased)
#     140         with tf.compat.v1.variable_scope(name, reuse=tf.AUTO_REUSE) as scope:
#     141             kernel = self.make_var('weights', shape=[k_h, k_w, c_i, c_o])
# --> 142             output = convolve(input, kernel)
#     143
#     144             if biased:
#
# ~\Coding\pspnet_test\network.py in <lambda>(i, k)
#     137         c_i = input.get_shape()[-1]
#     138
# --> 139         convolve = lambda i, k: tf.nn.conv2d(i, k, [1, s_h, s_w, 1], padding=padding,data_format=DEFAULT_DATAFORMAT)
#     140         with tf.compat.v1.variable_scope(name, reuse=tf.AUTO_REUSE) as scope:
#     141             kernel = self.make_var('weights', shape=[k_h, k_w, c_i, c_o])
#
# c:\users\yumin\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name, filters)
#    2008                            data_format=data_format,
#    2009                            dilations=dilations,
# -> 2010                            name=name)
#    2011
#    2012
#
# c:\users\yumin\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1069                   padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
#    1070                   explicit_paddings=explicit_paddings,
# -> 1071                   data_format=data_format, dilations=dilations, name=name)
#    1072   _result = _op.outputs[:]
#    1073   _inputs_flat = _op.inputs
#
# c:\users\yumin\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     365       # Need to flatten all the arguments into a list.
#     366       # pylint: disable=protected-access
# --> 367       g = ops._get_graph_from_inputs(_Flatten(keywords.values()))
#     368       # pylint: enable=protected-access
#     369     except AssertionError as e:
#
# c:\users\yumin\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\framework\ops.py in _get_graph_from_inputs(op_input_list, graph)
#    5977         graph = graph_element.graph
#    5978       elif original_graph_element is not None:
# -> 5979         _assert_same_graph(original_graph_element, graph_element)
#    5980       elif graph_element.graph is not graph:
#    5981         raise ValueError("%s is not from the passed-in graph." % graph_element)
#
# c:\users\yumin\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\framework\ops.py in _assert_same_graph(original_item, item)
#    5912   if original_item.graph is not item.graph:
#    5913     raise ValueError("%s must be from the same graph as %s." %
# -> 5914                      (item, original_item))
#    5915
#    5916
#
# ValueError: Tensor("conv1_1_3x3_s2/weights:0", shape=(3, 3, 3, 64), dtype=float32_ref) must be from the same graph as Tensor("ExpandDims_1:0", shape=(1, ?, ?, 3), dtype=float32).

# %%
# %%time
# Run and get result image
result=[]

for pred in preds :
    result.append(sess.run(pred))

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(15,10))

ax1.imshow(imread(img_path_list[0]))
ax1.axis('off')

ax2.imshow(result[0][0]/255.0)
ax2.axis('off')

ax3.imshow(imread(img_path_list[1]))
ax3.axis('off')

ax4.imshow(result[1][0]/255.0)
ax4.axis('off')

ax5.imshow(imread(img_path_list[2]))
ax5.axis('off')

ax6.imshow(result[2][0]/255.0)
ax6.axis('off')
